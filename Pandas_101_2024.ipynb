# %% [markdown]
# <a href="https://colab.research.google.com/github/RatchanonPa/python_dataviz2024/blob/main/Pandas_101_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library in pyton is package
import pandas

# %%
pandas.DataFrame({'A':[1, 2, 3], 'B':[2, 3, 4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/My Drive/dataviz_2024_DATA'

# %%
folktales_file_path = os.path.join(path,'folktales.csv')
print(folktales_file_path)
# Out:
# /content/drive/My Drive/dataviz_2024_DATA/folktales.csv

# %%
a = path + 'folktales.csv'
print(a)
# Out:
# /content/drive/My Drive/dataviz_2024_DATAfolktales.csv

# %%
folk_df = a

# %% [markdown]
# # Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียวหาย)

# %%
folk_df = pd.read_csv('/content/folktales.csv')
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# # Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os #จัดการ file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_folktales = '/content/drive/MyDrive/data_viz_2024_DATA/folktales.csv'

# %%
folk_df = pd.read_csv(path_to_folktales)
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
folk_df.head(15)
# Out:
#                                          title             type  \
# 0                                 ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                               ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                           ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                    บักหำน้อย           มุขตลก
# 4                                   รื้อบ่อน้ำ           มุขตลก
# 5   กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                               หลวงพ่อน้องงัว           มุขตลก
# 8                            หลวงพ่อกับเณรน้อย           มุขตลก
# 9                              หัวล้านหลื่นครู           มุขตลก
# 10                                 ซิ่นสองต่อน   นิทานประจำถิ่น
# 11           เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ           มุขตลก
# 12                                  แม่ใหญ่แฮก     ตำนานปรัมปรา
# 13          ทำไมมนุษย์จึงรู้จักการกินเมล็ดข้าว  นิทานอธิบายเหตุ
# ...

# %%
folk_df.tail()
# Out:
#                    title             type                 creator  \
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 221  <p>รายาบือราสะครองเมืองบรือดะ ทรงมีพระราชธิดาพ...  นิทานพื้นบ้าน     ไทย
# 222  <p>มีตำราหลวงพ่ออยู่เล่มหนึ่ง เป็นตำราที่ทายแม...  นิทานพื้นบ้าน     ไทย
# 223  <p>มีเต่าตัวหนึ่งเที่ยวหากินอยู่ตามชายป่าใกล้ท...  นิทานพื้นบ้าน     NaN
# 224  <p>นานมาแล้ว มีเทวดาอยู่องค์หนึ่งถูกพระอิศวรสา...  นิทานพื้นบ้าน    ไทย,
# 225  <p>ถ้ำเปอร์งง มีลำธารไหลลอดถ้ำออกไปสู่แม่น้ำปั...  นิทานพื้นบ้าน    ไทย,
#
#      temporal language rights                         license  \
# ...

# %%
folk_df.shape
#(row, column)
# Out:
# (226, 11)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
folk_df['title'][99]
# Out:
# 'เด็กโง่'

# %%
folk_df['creator'][99] # ชี้ column ก่อนแล้วค่อยชี้ว่าเป็นตัวไหนใน List
# Out:
# 'เรียบ รักสมบัติ'

# %% [markdown]
# iloc มองเป็น array

# %% [markdown]
# #### .iloc

# %%
folk_df.iloc[99,5]
# Out:
# 'ไทย,'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = folk_df[['title', 'type', 'creator', 'subject', 'spatial']]
smaller_table
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#            subject spatial
# 0    นิทานพื้นบ้าน     ไทย
# 1    นิทานพื้นบ้าน     ไทย
# 2    นิทานพื้นบ้าน     ไทย
# 3    นิทานพื้นบ้าน     ไทย
# 4    นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# #### ตัดเฉพาะ rows และ column ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice  (ใช้การไม่ค่อยได้เพราะไม่ค่อยสื่อ ว่าตัวเลขแต่ละตัวสื่อถึงอะไร)

# %%
folk_df.iloc[1:5,:]
# Out:
#                 title          type             creator  \
# 1      ขอคำกระฮอกด่อน  ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่    นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย        มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ        มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 1       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 2       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# 3       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %% [markdown]
# ## Table Query (Row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# ### อยากได้นิทานที่เป็นมุขตลก

# %%
# list ของ Logic เอา data ของแต่ละ row มาเปรียบเทียบกัน
# ถ้าเป็นมุขตลก จะเป็น true ไม่ใช่มุขตลกจะเป็น False
# เลือกเอาเฉพาะ data ที่เป็น True
folk_df['type']=='มุขตลก'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 221    False
# 222     True
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df[folk_df['type']=='มุขตลก']
# Out:
#                                           title    type              creator  \
# 3                                     บักหำน้อย  มุขตลก      สมหวัง ปานพายัพ
# 4                                    รื้อบ่อน้ำ  มุขตลก       บุญศรี เกสเสโร
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ  มุขตลก   พัชราภรณ์ เข็มเพชร
# 7                                หลวงพ่อน้องงัว  มุขตลก      สุบิน คำยางจ้อง
# 8                             หลวงพ่อกับเณรน้อย  มุขตลก  ปรางค์ทิพย์ บุญสีลา
# 9                               หัวล้านหลื่นครู  มุขตลก        ใจมา สมจันทร์
# 11            เซียงเมี่ยง ตอนหลอกเจ้าเมืองลงน้ำ  มุขตลก     เพ็ญนภา พันพินิจ
# 18                                       จับราว  มุขตลก          ชารี คำสีมา
# 19                               บักแหมบกับอีทา  มุขตลก      สุนีย์ คุณโพธิ์
# 20                             แม่เฒ่ากับลูกเขย  มุขตลก      สุนีย์ คุณโพธิ์
# 22                            หลวงพ่อกลัวผีหลอก  มุขตลก          เสาร์ จันกอ
# ...

# %% [markdown]
# #### quize 6 query data ในตาราง มาเฉพาะเลือก data มา 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logic ในการ query

# %% [markdown]
# แสดงวิธีทำดังนี้
#
#
# 1.   สร้าง list of logic
# 2.   query

# %%
list_log1 = 10*[True]
list_log2 = 15*[True]

# %%
list_logM = (226-25)*[False]

# %%
folk_df[list_log1+list_logM+list_log2]
# Out:
#                                           title             type  \
# 0                                  ตาบอดคลำช้าง   นิทานประจำถิ่น
# 1                                ขอคำกระฮอกด่อน     ตำนานปรัมปรา
# 2                            ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต
# 3                                     บักหำน้อย           มุขตลก
# 4                                    รื้อบ่อน้ำ           มุขตลก
# 5    กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ           มุขตลก
# 6                                 ตำนานกุดนางใย   นิทานประจำถิ่น
# 7                                หลวงพ่อน้องงัว           มุขตลก
# 8                             หลวงพ่อกับเณรน้อย           มุขตลก
# 9                               หัวล้านหลื่นครู           มุขตลก
# 211                              งูเหลือมคายพิษ  นิทานอธิบายเหตุ
# 212                             จระเข้กับจิ้งจก  นิทานอธิบายเหตุ
# 213                                     จอมคาถา           มุขตลก
# ...

# %%
# prompt: create list that has 226 where the first 10 and the last are true, the rest are false.

list_log1 = 10*[True]
list_log2 = 15*[True]
list_logM = (226-25)*[False]

# %% [markdown]
# ### การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %% [markdown]
# # HW5
# ใช้การ Query และ Data Slicing เพื่อตอบคำถามต่อไปนี้
#
#
#
# 1.   นิทานที่ยาวที่สุด และสั้นที่สุด(ไม่นับสัญลักษณ์พิเศษ)
# 2.   ชนิดของนิทาน (type) ที่มากที่สุดและน้อยที่สุด
# 3.   มี spatial ที่ไม่ใช่ ไทย กี่เรื่อง

# %% [markdown]
# ## อาจารย์พาทำ

# %%
# prompt: ลบ row ที่มีค่าว่างใน column description

folk_df_clean = folk_df.dropna(subset=['description'])
folk_df_clean
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
# prompt: เทียบปริมาณ data ก่อนและหลังลบ ค่าว่าง

print(f'จำนวน data ก่อนลบ = {folk_df.shape[0]}')
print(f'จำนวน data หลังลบ = {folk_df_clean.shape[0]}')
# Out:
# จำนวน data ก่อนลบ = 226
# จำนวน data หลังลบ = 218

# %%
# prompt: ลบ html tags และ html codes ออกจาก text ใน column description

# !pip install beautifulsoup4

from bs4 import BeautifulSoup

def remove_html_tags(text):
  soup = BeautifulSoup(text, 'html.parser')
  return soup.get_text()

folk_df_clean['description_clean'] = folk_df_clean['description'].apply(remove_html_tags)
# Out:
# ...
# <ipython-input-30-a611294cae4d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df_clean['description_clean'] = folk_df_clean['description'].apply(remove_html_tags)

# %%
folk_df_clean['description_clean'] = folk_df_clean['description'].apply(remove_html_tags)
folk_df_clean['description_clean'][0]
# Out:
# <ipython-input-31-7daedc5ef3c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df_clean['description_clean'] = folk_df_clean['description'].apply(remove_html_tags)
# ...

# %%
# prompt: ลบ \xa0 และ \n ไปด้วย

def remove_xa0_newline(text):
  text = text.replace('\xa0', '')
  text = text.replace('\n', '')
  return text

folk_df_clean['description_clean'] = folk_df_clean['description_clean'].apply(remove_xa0_newline)
folk_df_clean['description_clean'][0]
# Out:
# <ipython-input-32-0813313045b1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df_clean['description_clean'] = folk_df_clean['description_clean'].apply(remove_xa0_newline)
# ...

# %%
# prompt: description ของ row ไหนยาวและสั้นที่สุด print name และความยาว

folk_df_clean['len'] = folk_df_clean['description_clean'].str.len()
folk_df_clean

min_idx = folk_df_clean['len'].idxmin()
max_idx = folk_df_clean['len'].idxmax()

min_name = folk_df_clean.iloc[min_idx]['title']
min_len = folk_df_clean.iloc[min_idx]['len']

max_name = folk_df_clean.iloc[max_idx]['title']
max_len = folk_df_clean.iloc[max_idx]['len']

print(f'นิทานที่สั้นที่สุดคือ {min_name} : {min_len} ตัวอักษร')
print(f'นิทานที่ยาวที่สุดคือ {max_name} : {max_len} ตัวอักษร')
# Out:
# นิทานที่สั้นที่สุดคือ เสือทำไมจึงตัวลาย : 1495 ตัวอักษร
# นิทานที่ยาวที่สุดคือ ท้าวหมาหยุ๋ย : 7825 ตัวอักษร
# <ipython-input-33-afa043953753>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df_clean['len'] = folk_df_clean['description_clean'].str.len()

# %% [markdown]
# ## 5.2

# %%
# prompt: ลบค่าว่างใน column type

folk_df_clean_type = folk_df_clean.dropna(subset=['type'])
folk_df_clean_type
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
# prompt: ชนิดของนิทาน (type) ที่มีจำนวณ row มากและน้อยที่สุด

type_counts = folk_df_clean_type['type'].value_counts()
# หา index ของ type ที่มากที่สุด
max_index = type_counts.idxmax()
# หาจำนวน row ของ type ที่มากที่สุด
max_value = type_counts.max()
# หา index ของ type ที่น้อยที่สุด
min_index = type_counts.idxmin()
# หาจำนวน row ของ type ที่น้อยที่สุด
min_value = type_counts.min()

print(f"ชนิดของนิทานที่มีจำนวนมากที่สุดคือ {max_index} : {max_value}")
print(f"ชนิดของนิทานที่มีจำนวนน้อยที่สุดคือ {min_index} : {min_value}")
# Out:
# ชนิดของนิทานที่มีจำนวนมากที่สุดคือ มุขตลก : 46
# ชนิดของนิทานที่มีจำนวนน้อยที่สุดคือ นิทานเข้าแบบ : 1

# %% [markdown]
# ## ทำข้อ 5.2 แบบทำเอง

# %%
# group row ตาม column ที่กำหนด
folk_df.groupby('type').count()
# Out:
#                  title  creator  description  subject  spatial  temporal  \
# type
# ตำนานปรัมปรา         9        8            9        9        7         0
# นิทานชีวิต          41       22           40       41       35         0
# นิทานประจำถิ่น      26       15           25       26       24         0
# นิทานผี              8        2            8        8        8         0
# นิทานมหัศจรรย์      25       12           25       25       23         0
# นิทานวีรบุรุษ        3        0            3        3        3         0
# นิทานศาสนา           8        3            8        8        8         0
# นิทานสัตว์          15        5           14       15       12         0
# นิทานอธิบายเหตุ     39       25           39       39       32         0
# นิทานเข้าแบบ         1        0            1        1        1         0
# มุขตลก              51       33           46       51       47         0
#
#                  language  rights  license  source.uri
# type
# ...

# %%
# 5.3
folk_df['spatial'].unique()
# Out:
# array(['ไทย', 'ไทย,', nan, 'ราชบุรี ไทย,', 'พัทลุง ไทย', 'พัทลุง, ไทย',
#        'พัทลุง, ไทย,', 'สงขลา ไทย', 'นครศรีธรรมราช ไทย'], dtype=object)

# %%
folk_df = folk_df.dropna(subset=['spatial'])
folk_df
# Out:
#                        title             type                 creator  \
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 224            ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225      ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# ...

# %%
set(folk_df['spatial']) # set() แปลงให้ input เป็น set
# Out:
# {'นครศรีธรรมราช ไทย',
#  'พัทลุง ไทย',
#  'พัทลุง, ไทย',
#  'พัทลุง, ไทย,',
#  'ราชบุรี ไทย,',
#  'สงขลา ไทย',
#  'ไทย',
#  'ไทย,'}

# %%
folk_df.shape[0]
# Out:
# 200

# %% [markdown]
# ## ทำเอง

# %% [markdown]
# ### My Prompt
# **attached [folktales.csv]**
#
# **Prompt**
#  > Use Query and Data Slicing to answer the following questions.
#
#
#
#
#
# - The longest story and the shortest (not counting special symbols)
# - The most and least type of story (type).
# - How many spatial stories are there that are not Thai?

# %% [markdown]
# ### Process Overview
#
# 1. **Load the Data**:
#    - Read the dataset from the provided CSV file.
#
# 2. **Clean the Data**:
#    - Remove HTML tags from the `description` column.
#    - Unescape HTML entities.
#    - Remove special symbols from the cleaned descriptions.
#
# 3. **Calculate Description Lengths**:
#    - Compute the length of each cleaned description to identify the longest and shortest stories.
#
# 4. **Analyze Story Types**:
#    - Count the occurrences of each unique value in the `type` column to determine the most and least common story types.
#
# 5. **Count Non-Thai Spatial Stories**:
#    - Filter the dataset to count the number of stories where the `spatial` value is not 'ไทย' (Thai).
#
# ### Detailed Steps with Code
#
# 1. **Load the Data**:
#     ```python
#     import pandas as pd
#
#     # Load the dataset
#     file_path = '/mnt/data/folktales.csv'
#     folk_df = pd.read_csv(file_path)
#     ```
#
# 2. **Clean the Data**:
#     ```python
#     from html import unescape
#
#     # Fill NaN values in the description column with empty strings
#     folk_df['description_clean'] = folk_df['description'].fillna('')
#
#     # Remove HTML tags
#     folk_df['description_clean'] = folk_df['description_clean'].str.replace(r'<[^>]*>', '', regex=True)
#
#     # Unescape HTML entities
#     folk_df['description_clean'] = folk_df['description_clean'].apply(unescape)
#
#     # Remove special symbols
#     folk_df['description_clean'] = folk_df['description_clean'].str.replace(r'[^\w\s]', '', regex=True)
#     ```
#
# 3. **Calculate Description Lengths**:
#     ```python
#     # Calculate the length of each description
#     folk_df['description_length'] = folk_df['description_clean'].str.len()
#     ```
#
# 4. **Identify Longest and Shortest Stories**:
#     ```python
#     # Identify the longest and shortest stories
#     longest_story = folk_df.loc[folk_df['description_length'].idxmax()]
#     shortest_story = folk_df.loc[folk_df['description_length'].idxmin()]
#     ```
#
# 5. **Analyze Story Types**:
#     ```python
#     # Determine the most and least common types of stories
#     story_type_counts = folk_df['type'].value_counts()
#     most_common_type = story_type_counts.idxmax()
#     least_common_type = story_type_counts.idxmin()
#     ```
#
# 6. **Count Non-Thai Spatial Stories**:
#     ```python
#     # Count the number of spatial stories that are not Thai
#     non_thai_spatial_stories_count = folk_df[folk_df['spatial'] != 'ไทย'].shape[0]
#     ```
#
# ### Output the Results
#
# ```python
# # Output the results
# print("Longest Story:")
# print("Title:", longest_story['title'])
# print("Description Length:", longest_story['description_length'])
# print()
#
# print("Shortest Story:")
# print("Title:", shortest_story['title'])
# print("Description Length:", shortest_story['description_length'])
# print()
#
# print("Most Common Type of Story:", most_common_type)
# print("Least Common Type of Story:", least_common_type)
# print("Number of Spatial Stories That Are Not Thai:", non_thai_spatial_stories_count)

# %%
import pandas as pd
from html import unescape

# %%
# 1. นิทานที่ยาวที่สุด และสั้นที่สุด(ไม่นับสัญลักษณ์พิเศษ)
# Clean the 'description' column by removing HTML tags and special symbols
folk_df['description_clean'] = folk_df['description'].fillna('')  # Fill NaN values with empty strings
folk_df['description_clean'] = folk_df['description_clean'].str.replace(r'<[^>]*>', '', regex=True)
folk_df['description_clean'] = folk_df['description_clean'].apply(unescape)  # Unescape HTML entities
folk_df['description_clean'] = folk_df['description_clean'].str.replace(r'[^\w\s]', '', regex=True)
# Out:
# <ipython-input-42-859a02965d74>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df['description_clean'] = folk_df['description'].fillna('')  # Fill NaN values with empty strings
# <ipython-input-42-859a02965d74>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df['description_clean'] = folk_df['description_clean'].str.replace(r'<[^>]*>', '', regex=True)
# <ipython-input-42-859a02965d74>:5: SettingWithCopyWarning:
# ...

# %%
folk_df['description_clean'].head(5)
# Out:
# 0            มคนตาบอดหกคน ซงเปนเพอนรกกนอยทบานจนตคาม...
# 1          ในขณะนนมพญาผหนงชอวา พญาขอม ครองเมองหนองห...
# 2    ครงหนงนานมาแลวในฤดฝน มการเตรยมปกดำกลาขาว ทกครอ...
# 3    เรองมอยวา ณ โรงเรยนแหงหนงของภาคอสาน กำลงตรวจสข...
# 4    วนหนงพอตากบลกเขยพากนไปรอบอนำใช พอขดไปขดมาพอตาไ...
# Name: description_clean, dtype: object

# %%
# Calculate the length of each description
folk_df['description_length'] = folk_df['description_clean'].str.len()
# Out:
# <ipython-input-44-67b0e9a9074c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folk_df['description_length'] = folk_df['description_clean'].str.len()

# %%
# Identify the longest and shortest stories
longest_story = folk_df.loc[folk_df['description_length'].idxmax()]
shortest_story = folk_df.loc[folk_df['description_length'].idxmin()]

# %%
# Output the results
print(f"นิทานที่ยาวที่สุดคือ {longest_story['title']} โดยมีความยาว {longest_story['description_length']} ตัวอักษร")
print("-------------------------------------------------------------------------------------------------------------------")
print(f"นิทานที่สั้นที่สุดคือ {shortest_story['title']} โดยมีความยาว {shortest_story['description_length']} ตัวอักษร")
# Out:
# นิทานที่ยาวที่สุดคือ ท้าวหมาหยุ๋ย โดยมีความยาว 6044 ตัวอักษร
# -------------------------------------------------------------------------------------------------------------------
# นิทานที่สั้นที่สุดคือ บอดตาใส โดยมีความยาว 0 ตัวอักษร

# %%
folk_df[folk_df['title']=='บอดตาใส']
# Out:
#       title    type         creator description        subject spatial  \
# 27  บอดตาใส  มุขตลก  สดศรี  ศิริเวช         NaN  นิทานพื้นบ้าน    ไทย,
#
#     temporal language rights                         license  \
# 27       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                            source.uri description_clean  \
# 27  https://www.sac.or.th/databases/folktales/folk...
#
#     description_length
# 27                   0

# %%
# 2. ชนิดของนิทาน (type) ที่มากที่สุดและน้อยที่สุด
# Determine the most and least types of stories
story_type_counts = folk_df['type'].value_counts()
most_type = story_type_counts.idxmax()
least_type = story_type_counts.idxmin()

# %%
# prompt: count number of each type

# Count the number of each type
story_type_counts = folk_df['type'].value_counts()

# Display the counts
print(story_type_counts)
# Out:
# type
# มุขตลก             47
# นิทานชีวิต         35
# นิทานอธิบายเหตุ    32
# นิทานประจำถิ่น     24
# นิทานมหัศจรรย์     23
# นิทานสัตว์         12
# นิทานผี             8
# นิทานศาสนา          8
# ตำนานปรัมปรา        7
# นิทานวีรบุรุษ       3
# นิทานเข้าแบบ        1
# Name: count, dtype: int64

# %%
print(f"ชนิดของนิทานที่มากที่สุดคือ {most_type} โดยมีจำนวน {folk_df['type'].value_counts().max()} เรื่อง ") # Use value_counts().max() to get the count of the most frequent type
print(f"ชนิดของนิทานที่น้อยที่สุดคือ {least_type} โดยมีจำนวน {folk_df['type'].value_counts().min()} เรื่อง")
# Out:
# ชนิดของนิทานที่มากที่สุดคือ มุขตลก โดยมีจำนวน 47 เรื่อง
# ชนิดของนิทานที่น้อยที่สุดคือ นิทานเข้าแบบ โดยมีจำนวน 1 เรื่อง

# %%
folk_df[folk_df['type']=='นิทานเข้าแบบ']
# Out:
#              title          type creator  \
# 151  ท้าวเสียวสวาด  นิทานเข้าแบบ     NaN
#
#                                            description        subject spatial  \
# 151  <p>ท้าวเสียวสวาด เป็นขุนนางผู้เฉลียวฉลาดคนหนึ่...  นิทานพื้นบ้าน     ไทย
#
#      temporal language rights                         license  \
# 151       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
#
#                                             source.uri  \
# 151  https://www.sac.or.th/databases/folktales/folk...
#
#                                      description_clean  description_length
# 151  ทาวเสยวสวาด เปนขนนางผเฉลยวฉลาดคนหนง ไดถวายคำสอ...                 808

# %%
# 3. มี spatial ที่ไม่ใช่ ไทย กี่เรื่อง
# Count the number of spatial stories that are not Thai
non_thai_spatial_stories_count = folk_df[folk_df['spatial'] != 'ไทย'].shape[0]
print(f"มี spatial ที่ไม่ใช่ ไทย : {non_thai_spatial_stories_count} เรื่อง")
# Out:
# มี spatial ที่ไม่ใช่ ไทย : 120 เรื่อง

# %% [markdown]
# 3. หาจำนวนผู้ป่วยที่เป็นคน "**คนต่างชาติเดินทางมาจากต่างประเทศ**"

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None```,  ```NA```(not autorized), and  ```NaN``` (not a number)

# %% [markdown]
# not autorized ไม่สามารถ access ข้อมูลได้

# %%
folk_df = pd.read_csv('folktales.csv')
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = folk_df.copy()

# %%
this_data.shape
# Out:
# (226, 11)

# %%
print(this_data.shape)
print(this_data.dropna().shape)
# ถ้าไม่ระบุข้อมูลหายหมด
# Out:
# (226, 11)
# (0, 11)

# %%
this_data.dropna(inplace=True)

# %%
this_data
# Out:
# Empty DataFrame
# Columns: [title, type, creator, description, subject, spatial, temporal, language, rights, license, source.uri]
# Index: []

# %%
this_data = this_data.dropna(inplace=True) #ฟังก์ชันที่ไม่ return อะไรเลย this_data เลยรับค่า None

# %%
this_data
print(this_data)
# Out:
# None

# %% [markdown]
# ## ลบเฉพาะค่าว่างใน column ที่เราต้องใช้

# %%
import pandas as pd
folk_df = pd.read_csv('folktales.csv')
folk_df
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data = folk_df.dropna(subset=['title', 'description', 'type'])
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
folk_df['type'].mode()
#คุณภาพใช้ mode ปริมาณใช้ mean
# Out:
# 0    มุขตลก
# Name: type, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull() #null return true, not null return false
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any() #เช็ค column ไหนไม่เป็น null บ้าง
# เอาทุกค่าใน list มา OR กัน
# ใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True
# Out:
# False

# %%
folk_df['type'].isnull().all() # เอาทุกค่าใน list มา AND กัน
# Out:
# False

# %% [markdown]
# # Quize7-8  นิทานเรื่องไหนที่ค่า spatial เป็นค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df['spatial'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223     True
# 224    False
# 225    False
# Name: spatial, Length: 226, dtype: bool

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %%
folk_df['spatial'].isnull().all()
# Out:
# False

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicated)

# %%
folk_df['title'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: title, Length: 226, dtype: bool

# %%
folk_df['title'].duplicated().any()
# Out:
# True

# %%
folk_df[folk_df['title'].duplicated(keep=False)]['title']
# Out:
# 2      ก่องข้าวน้อยฆ่าแม่
# 32     ก่องข้าวน้อยฆ่าแม่
# 34              พญาคันคาก
# 38           กำพร้าผีน้อย
# 43     ก่องข้าวน้อยฆ่าแม่
# 49               ผีกองกอย
# 75              พญาคันคาก
# 95           กำพร้าผีน้อย
# 100              ผีกองกอย
# 142              ผีกองกอย
# Name: title, dtype: object

# %%
# ใส่ค่ากลาง
folk_df.fillna({'type':folk_df['type'].mode()[0]})
# Out:
#                    title             type                 creator  \
# 0           ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1         ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2     ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3              บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4             รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                   ...              ...                     ...
# 221          ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222            ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
# 223   เต่ากับพระพุทธเจ้า  นิทานอธิบายเหตุ                     NaN
# 224        ถ้ำคูหาสวรรค์   นิทานประจำถิ่น                     NaN
# 225  ถ้ำทองและถ้ำเปอร์งง   นิทานประจำถิ่น                     NaN
#
#                                            description        subject spatial  \
# 0    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ## แก้ค่าว่าง
#
#
# 1. ลบไปเลย
# 2. เลือกลบเฉพาะสิ่งที่ไม่สนใจ
# 3. เติมด้วยค่ากลาง (mean, mode, and median)
# 4. ประมาณค่าด้วยวิธีทางสถิติต่าง ๆ

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = folk_df[['title','type','creator']].dropna()
this_data
# Out:
#                        title             type                 creator
# 0               ตาบอดคลำช้าง   นิทานประจำถิ่น        อ่อนตา ประกาเวสา
# 1             ขอคำกระฮอกด่อน     ตำนานปรัมปรา               พ่อใหญ่นู
# 2         ก่องข้าวน้อยฆ่าแม่       นิทานชีวิต      หนูเวียง แก้วเวียง
# 3                  บักหำน้อย           มุขตลก         สมหวัง ปานพายัพ
# 4                 รื้อบ่อน้ำ           มุขตลก          บุญศรี เกสเสโร
# ..                       ...              ...                     ...
# 217                   เณรทอง   นิทานประจำถิ่น         รมย์   เผือกแสง
# 218         ดวงอาทิตย์กับไก่  นิทานอธิบายเหตุ         รมย์   เผือกแสง
# 219  ต้นลำพูกับนิทานหิ่งห้อย  นิทานอธิบายเหตุ          อารี  เส้งวั่น
# 221              ตำนานมะโย่ง     ตำนานปรัมปรา  หร้อหวาน   วัชรจิรโสภณ
# 222                ตำราหมอดู           มุขตลก        มาลี   พันธ์วงศ์
#
# [125 rows x 3 columns]

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
for each_row in this_data.iterrows():
 print(each_row, end = '\n**********************************\n')
# Out:
# (0, title                                               ตาบอดคลำช้าง
# type                                              นิทานประจำถิ่น
# creator                                         อ่อนตา ประกาเวสา
# description    <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...
# subject                                            นิทานพื้นบ้าน
# spatial                                                      ไทย
# temporal                                                     NaN
# language                                                     ไทย
# rights                                                       NaN
# license                           สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# source.uri     https://www.sac.or.th/databases/folktales/folk...
# Name: 0, dtype: object)
# **********************************
# (1, title                                             ขอคำกระฮอกด่อน
# type                                                ตำนานปรัมปรา
# ...

# %% [markdown]
# ## Quize9
#
# *   วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่องทั้งหมดกี่เรื่อง และเป็นเรื่องอะไรบ้าง
# *   มีคำดังกล่าวใน นิทานชีวิต หรือนิทานประจำถิ่นมากกว่ากัน
# * คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่หรือพ่อมากที่สุด

# %%
#prompt: วนลูปนับว่ามีนิทานที่มีคำว่า แม่หรือพ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง

count_mom_dad = 0
list_story = []
for i, each_row in this_data.iterrows():
  if 'แม่' in each_row['title'] or 'พ่อ' in each_row['title']:
    count_mom_dad += 1
    list_story.append(each_row['title'])
print(f'มีนิทานที่มีคำว่า แม่หรือพ่อ ในชื่อเรื่อง ทั้งหมด {count_mom_dad} เรื่อง')
print(f'รายชื่อนิทาน: {list_story}')
# Out:
# มีนิทานที่มีคำว่า แม่หรือพ่อ ในชื่อเรื่อง ทั้งหมด 19 เรื่อง
# รายชื่อนิทาน: ['ก่องข้าวน้อยฆ่าแม่', 'หลวงพ่อน้องงัว', 'หลวงพ่อกับเณรน้อย', 'แม่ใหญ่แฮก', 'ปัญญาของพ่อ', 'แม่เฒ่ากับลูกเขย', 'หลวงพ่อกลัวผีหลอก', 'หลวงพ่อเข้าลอดช่อง', 'ลูกหลงพ่อ', 'ก่องข้าวน้อยฆ่าแม่', 'คนจีนกับหลวงพ่อเจ้าอาวาส', 'หลวงพ่อกินขี้ไก่โป่', 'หลวงพ่อม้าน้อยหลังแอ่น', 'พ่อเฒ่ากับลูกเขยกินข้าวนำกัน', 'พ่อใหญ่หัวล้าน', 'หลวงพ่อกะทอเกลือ', 'แม่หม้ายตาโป', 'ด้ามมีดพ่อท่าน', 'พระคุณแม่โพสพ']

# %%
# prompt: มีคำว่าพ่อ หรือแม่ในนิทาน type นิทานชีวิตหรือนิทานประจำถิ่นมากกว่ากัน

count_life = 0
count_local = 0
for i, each_row in this_data.iterrows():
  if 'แม่' in each_row['title'] or 'พ่อ' in each_row['title']:
    if each_row['type'] == 'นิทานชีวิต':
      count_life += 1
    elif each_row['type'] == 'นิทานประจำถิ่น':
      count_local += 1

if count_life > count_local:
  print('มีคำว่าพ่อ หรือแม่ในนิทาน type นิทานชีวิตมากกว่า')
elif count_local > count_life:
  print('มีคำว่าพ่อ หรือแม่ในนิทาน type นิทานประจำถิ่นมากกว่า')
else:
  print('มีคำว่าพ่อ หรือแม่ในนิทาน type นิทานชีวิตและนิทานประจำถิ่นเท่ากัน')
# Out:
# มีคำว่าพ่อ หรือแม่ในนิทาน type นิทานชีวิตและนิทานประจำถิ่นเท่ากัน

# %%
# prompt: คนเเต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่หรือพ่อ มากที่สุด

creator_counts = {}
for i, each_row in this_data.iterrows():
  if 'แม่' in each_row['title'] or 'พ่อ' in each_row['title']:
    creator = each_row['creator']
    if creator not in creator_counts:
      creator_counts[creator] = 0
    creator_counts[creator] += 1

max_count = 0
most_frequent_creator = None
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    most_frequent_creator = creator

print(f"คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่า แม่หรือพ่อ มากที่สุดคือ: {most_frequent_creator} ({max_count} เรื่อง)")
# Out:
# คนแต่งที่ชอบแต่งนิทานที่มีชื่อเรื่องว่า แม่หรือพ่อ มากที่สุดคือ: หนูเวียง แก้วเวียง (2 เรื่อง)

# %%
this_data['creator'].count()
# Out:
# 125

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า พ่อ หรือ แม่ ออกมา

count_mom_dad = 0
for i in range(this_data.shape[0]):
  if 'แม่' in this_data.iloc[i,0] or 'พ่อ' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
    count_mom_dad += 1
print(f'มีนิทานที่มีคำว่า พ่อ หรือ แม่ อยู่ในชื่อเรื่องทั้งหมด {count_mom_dad} เรื่อง')
# Out:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ
# มีนิทานที่มีคำว่า พ่อ หรือ แม่ อยู่ในชื่อเรื่องทั้งหมด 19 เรื่อง

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# 4. print ชื่อนิทานทั้งหมดที่มีคำว่า ป้า ออกมา

# %%
# prompt:  print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา โดยใช้ .iloc

count = 0
list_grandpa = []
for i in range(folk_df.shape[0]):
  if 'ปู่' in folk_df.iloc[i,0]:
    count += 1
    list_grandpa.append(folk_df.iloc[i,0])
print(f'มีนิทานที่มีคำว่า ปู่ ในชื่อเรื่อง ทั้งหมด {count} เรื่อง')
print(f'รายชื่อนิทาน: {list_grandpa}')
# Out:
# มีนิทานที่มีคำว่า ปู่ ในชื่อเรื่อง ทั้งหมด 2 เรื่อง
# รายชื่อนิทาน: ['ปู่ปะหลาน', 'เขาปู่เขาย่า']

# %% [markdown]
# ## Dataset ใหม่ที่มีตัวเลข

# %%
import pandas as pd
movie_df = pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (11941, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
movie_df.dropna().shape
# Out:
# (4360, 10)

# %%
# prompt: จาก movie_df.dropna().shape ข้อมูลหายไปกี่เปอร์เซ็น

# Calculate the number of rows before dropping NA
num_rows_before = movie_df.shape[0]

# Calculate the number of rows after dropping NA
num_rows_after = movie_df.dropna().shape[0]

# Calculate the number of rows lost
num_rows_lost = num_rows_before - num_rows_after

# Calculate the percentage of data lost
percentage_lost = (num_rows_lost / num_rows_before) * 100

# Print the result
print(f"ข้อมูลหายไป {percentage_lost:.2f} เปอร์เซ็น")
# Out:
# ข้อมูลหายไป 63.49 เปอร์เซ็น

# %%
movie_df = movie_df.dropna()

# %%
# Clean the data
movie_df['Rating'] = pd.to_numeric(movie_df['Rating'], errors='coerce')
movie_df['Votes'] = pd.to_numeric(movie_df['Votes'].str.replace(',', ''), errors='coerce')

# %%
# Handle 'Year' column
movie_df['Year'] = movie_df['Year'].astype(str).str.replace('-', '')
movie_df['Year'] = pd.to_numeric(movie_df['Year'], errors='coerce')

# %%
movie_df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019.0  109 min
# 3                                 #Yaaram  2019.0  110 min
# 5                    ...Aur Pyaar Ho Gaya  1997.0  147 min
# 6                               ...Yahaan  2005.0  142 min
# 8                      ?: A Question Mark  2012.0   82 min
# ...                                   ...     ...      ...
# 11935                      Road to Ladakh  2003.0   50 min
# 11936                      Road to Sangam  2009.0  135 min
# 11938                         Road, Movie  2009.0   95 min
# 11939                      Roadside Romeo  2008.0   93 min
# 11940                      Roam Rome Mein  2019.0  107 min
#
#                               Genre  Rating  Votes               Director  \
# 1                             Drama     7.0      8          Gaurav Bakshi
# 3                   Comedy, Romance     4.4     35             Ovais Khan
# ...

# %%
# prompt: หาค่ากลางของจำนวนหนัง

# หาจำนวนหนังที่กำกับโดยผู้กำกับแต่ละคน
movies_per_director = movie_df['Director'].value_counts()

# คำนวณค่ากลาง
average_movies_per_director = movies_per_director.mean()
median_movies_per_director = movies_per_director.median()
mod_movies_per_director = movies_per_director.mode()
print(f"ค่าเฉลี่ยของจำนวนหนังที่กำกับโดยผู้กำกับแต่ละคน: {average_movies_per_director:.2f}")
print(f"มัธทยฐานของจำนวนหนังที่กำกับโดยผู้กำกับแต่ละคน: {median_movies_per_director:.2f}")
# Access the first element of the mode Series and convert it to a float for formatting
print(f"ฐานนิยมของจำนวนหนังที่กำกับโดยผู้กำกับแต่ละคน: {float(mod_movies_per_director[0]):.2f}")

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year       Rating          Votes
# count  4360.000000  4360.000000    4360.000000
# mean   1995.766284     5.891284    2716.892431
# std      19.813300     1.379394   14656.767320
# min    1931.000000     1.400000       5.000000
# 25%    1982.000000     5.000000      29.000000
# 50%    2001.000000     6.100000     128.000000
# 75%    2013.000000     6.900000     883.250000
# max    2021.000000    10.000000  591417.000000

# %%
# prompt: Which director has the most number of movies

movie_df['Director'].value_counts().idxmax()
# Out:
# 'David Dhawan'

# %%
# prompt: สร้างตารางของ Director ที่มี name เยอะที่สุด โดยสร้างตารางเต็ม ๆ เอาแค่คนที่มีหนังเยอะสุด

# หา Director ที่มีชื่อซ้ำกันมากที่สุด
most_frequent_director = movie_df['Director'].value_counts().idxmax()

# สร้างตารางเฉพาะ Director ที่มีชื่อซ้ำกันมากที่สุด
most_frequent_director_df = movie_df[movie_df['Director'] == most_frequent_director]

# แสดงตาราง
most_frequent_director_df
# Out:
#                                     Name    Year Duration  \
# 239                          Aag Ka Gola  1990.0  180 min
# 397                            Aandhiyan  1990.0  145 min
# 408                              Aankhen  1993.0  170 min
# 1008                               Andaz  1994.0  167 min
# 1596              Bade Miyan Chote Miyan  1998.0  140 min
# 1794                       Banarasi Babu  1997.0  126 min
# 2408                          Biwi No. 1  1999.0  159 min
# 2478                       Bol Radha Bol  1992.0  164 min
# 2754                      Chal Mere Bhai  2000.0  136 min
# 2903                     Chashme Baddoor  2013.0  121 min
# 3098                  Chor Machaaye Shor  2002.0  145 min
# 3230                        Coolie No. 1  1995.0  143 min
# 3232                        Coolie No. 1  2020.0  134 min
# 3562                     Deewana Mastana  1997.0  140 min
# 4037                     Do Knot Disturb  2009.0  126 min
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == most_frequent_director]['Rating'].mean()
# Out:
# 5.205714285714286

# %%
movie_df[movie_df['Director'] == most_frequent_director].describe()
# Out:
#               Year     Rating         Votes
# count    35.000000  35.000000     35.000000
# mean   2000.342857   5.205714   4811.914286
# std       7.650232   1.043733   9562.784481
# min    1989.000000   2.900000     23.000000
# 25%    1995.500000   4.600000    823.500000
# 50%    1999.000000   5.100000   2654.000000
# 75%    2003.000000   6.100000   4912.000000
# max    2020.000000   6.700000  56232.000000

# %% [markdown]
# # HW6 บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง
# (ทำสไลด์พรี 3 นาที)
# 1:14
# ทำการวิเคราะห์ข้อมูลจากไฟล์เพื่อหาว่าใครคือผู้กำกับชั้นนำของอินเดีย 3 คน และทำไมถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง โดยมีเกณคือ มี rating สูงสุด และ จำนวนเรื่องที่กำกับสูงสุด และ จำนวนโหวตสูงสุด พร้อมสร้างสไลด์และบทพูดเพื่อนำเสนอภายใน 3 นาที

# %%
# Group by director and calculate metrics
director_stats = movie_df.groupby('Director').agg({
    'Rating': ['mean', 'count'],
    'Votes': 'sum'
}).reset_index()

director_stats.columns = ['Director', 'Avg_Rating', 'Movie_Count', 'Total_Votes']

# Filter directors with at least 3 movies and 1000 total votes
qualified_directors = director_stats[(director_stats['Movie_Count'] >= 3) & (director_stats['Total_Votes'] >= 1000)]

# Sort by average rating and get top 3
top_directors = qualified_directors.sort_values('Avg_Rating', ascending=False).head(3)

print(top_directors)
# Out:
#              Director  Avg_Rating  Movie_Count  Total_Votes
# 1327  Rajkumar Hirani    8.150000            4       645942
# 1085    Nitesh Tiwari    7.975000            4       208778
# 1663    Shekhar Kapur    7.933333            3        22740

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
